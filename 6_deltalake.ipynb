# %% [markdown]
# ### **Table utility commands**

# %%
# %sql
describe deltalakegautam.default.firsttable

# %%
# %sql
describe detail deltalakegautam.default.firsttable;

# %%
# %sql 
describe extended deltalakegautam.default.firsttable;

# %%
# %sql
describe history delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/`

# %%
# %sql
select * from delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/`

# %% [markdown]
# #Time Travelling

# %%
# %sql
restore delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/` to version as of 2

# %%
# %sql
select * from delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/`

# %%
# %sql
select * from delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/` version as of 1

# %%
# %sql
select * from delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/` timestamp as of '2026-07-02T06:42:07.000+00:00'

# %%
# %sql
show tblproperties delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/`;

# %% [markdown]
# #VACCUUM Command

# %%
# %sql
vacuum delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/` retain 0 hours;

# %%
# %sql
create table deltalakegautam.default.clonetbl
clone delta.`/Volumes/deltalakegautam/default/deltavol/dmlsink/` version as of 1

# %%
# %sql
select * from deltalakegautam.default.clonetbl

# %%
# %sql
create table deltalakegautam.default.clonetblshallow
shallow clone deltalakegautam.default.clonetbl;
    
select * from deltalakegautam.default.clonetblshallow
